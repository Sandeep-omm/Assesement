# %% [markdown]
# <a href="https://colab.research.google.com/github/Sandeep-omm/Assesement/blob/main/Assesment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from getpass import getpass

# Ask securely for your token (input hidden)
token = getpass("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 ")

# Note: No curly braces, no %7B or %7D — clean URL
# !git clone https://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@github.com/bettrhq-assessments/flask-react-assessment-Sandeep-omm.git
# Out:
# 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 ··········
# Cloning into 'flask-react-assessment-Sandeep-omm'...
# remote: Enumerating objects: 428, done.
# remote: Counting objects: 100% (24/24), done.
# remote: Compressing objects: 100% (19/19), done.
# remote: Total 428 (delta 5), reused 5 (delta 5), pack-reused 404 (from 1)
# Receiving objects: 100% (428/428), 1.91 MiB | 10.58 MiB/s, done.
# Resolving deltas: 100% (45/45), done.

# %%
# %cd flask-react-assessment-Sandeep-omm
# !ls
# Out:
# /content/flask-react-assessment-Sandeep-omm
# config			 Makefile	     sonar-project.properties
# docker-compose.dev.yml	 package.json	     src
# docker-compose.test.yml  package-lock.json   tailwind.config.js
# Dockerfile		 Pipfile	     temporal-sql.yaml
# docs			 Pipfile.lock	     tests
# lib			 postcss.config.cjs  tsconfig.json
# lint-staged.config.js	 README.md

# %%
# !pip install flask flask_sqlalchemy requests

# %%
# !python src/app.py
# Out:
# python3: can't open file '/content/flask-react-assessment-Sandeep-omm/src/app.py': [Errno 2] No such file or directory

# %%
from src.app import app   # adjust if your file path differs

client = app.test_client()

# Create a new comment
res = client.post('/comments', json={"task_id": 1, "text": "Testing comment"})
print("Add:", res.get_json())

# Retrieve all comments for task_id 1
res = client.get('/comments/1')
print("Get:", res.get_json())

# Update the first comment
comment_id = res.get_json()[0]["id"]
res = client.put(f"/comments/{comment_id}", json={"text": "Updated comment"})
print("Update:", res.get_json())

# Delete it
res = client.delete(f"/comments/{comment_id}")
print("Delete:", res.get_json())
# Out:
# Add: {'created_at': 'Wed, 05 Nov 2025 16:05:04 GMT', 'id': 1, 'task_id': 1, 'text': 'Testing comment', 'updated_at': None}
# Get: [{'created_at': 'Wed, 05 Nov 2025 16:05:04 GMT', 'id': 1, 'task_id': 1, 'text': 'Testing comment', 'updated_at': None}]
# Update: {'created_at': 'Wed, 05 Nov 2025 16:05:04 GMT', 'id': 1, 'task_id': 1, 'text': 'Updated comment', 'updated_at': 'Wed, 05 Nov 2025 16:05:04 GMT'}
# Delete: {'message': 'Comment deleted'}

# %%
# !pip install flask-ngrok

# %%
from flask_ngrok import run_with_ngrok
run_with_ngrok(app)

# %%
from src.app import app   # adjust if app.py is elsewhere

client = app.test_client()

# ---- Create comment ----
res = client.post('/comments', json={"task_id": 1, "text": "Hello Flask!"})
print("Add:", res.get_json())

# ---- Get comments ----
res = client.get('/comments/1')
print("Get:", res.get_json())

# ---- Update comment ----
comment_id = res.get_json()[0]["id"]
res = client.put(f"/comments/{comment_id}", json={"text": "Updated text"})
print("Update:", res.get_json())

# ---- Delete comment ----
res = client.delete(f"/comments/{comment_id}")
print("Delete:", res.get_json())
# Out:
# Add: {'created_at': 'Wed, 05 Nov 2025 16:05:17 GMT', 'id': 1, 'task_id': 1, 'text': 'Hello Flask!', 'updated_at': None}
# Get: [{'created_at': 'Wed, 05 Nov 2025 16:05:17 GMT', 'id': 1, 'task_id': 1, 'text': 'Hello Flask!', 'updated_at': None}]
# Update: {'created_at': 'Wed, 05 Nov 2025 16:05:17 GMT', 'id': 1, 'task_id': 1, 'text': 'Updated text', 'updated_at': 'Wed, 05 Nov 2025 16:05:17 GMT'}
# Delete: {'message': 'Comment deleted'}

# %%
# !pip install pytest

# %%
# !pytest -v tests/test_comment_api.py
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.12.12, pytest-8.4.2, pluggy-1.6.0 -- /usr/bin/python3
# cachedir: .pytest_cache
# rootdir: /content/flask-react-assessment-Sandeep-omm/tests
# configfile: pyproject.toml
# plugins: anyio-4.11.0, langsmith-0.4.38, typeguard-4.4.4
# collected 4 items
#
# tests/test_comment_api.py::test_add_comment PASSED                       [ 25%]
# tests/test_comment_api.py::test_get_comments PASSED                      [ 50%]
# tests/test_comment_api.py::test_update_comment PASSED                    [ 75%]
# tests/test_comment_api.py::test_delete_comment PASSED                    [100%]
#
# ============================== 4 passed in 0.70s ===============================

# %%
# !git add src/app.py tests/test_comment_api.py

# %%
# !git commit -m "Task 1: Implement Comment CRUD APIs and add automated tests"
# Out:
# Author identity unknown
#
# *** Please tell me who you are.
#
# Run
#
#   git config --global user.email "you@example.com"
#   git config --global user.name "Your Name"
#
# to set your account's default identity.
# Omit --global to set the identity only in this repository.
#
# fatal: unable to auto-detect email address (got 'root@d949ba953ace.(none)')

# %%
# !git push origin main
# Out:
# Everything up-to-date

# %%
# !git checkout -b task-1-comment-api
# !git push origin task-1-comment-api
# Out:
# Switched to a new branch 'task-1-comment-api'
# Everything up-to-date
